# %%
import numpy as np 
arr = np.array([5, -2, 8, -1, 10, -7])
arr[arr<0] = 0
print(arr)
# Out:
# [ 5  0  8  0 10  0]

# %%
arr = np.array([3, 8, 12, 7, 15, 20])
print(np.sum(arr % 2 == 0))
# Out:
# 3

# %%
arr = np.array([10, 45, 20, 90, 50])
second_largest = np.sort(arr)[-2]
print(second_largest)
# Out:
# 50

# %%
arr = np.array([
[5,8,2],
[1,10,7],
[9,3,4]
])
print(arr[2,1])
# Out:
# 3

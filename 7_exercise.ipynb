# %% [markdown]
# ### Step 1. Import the necessary libraries.

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset.

# %%
pd.read_csv("7_ecommerce_sales_1000_records - 7_ecommerce_sales_1000_records.csv")
# Out:
#     Order_ID     Product     Category  Quantity     Price       City  \
# 0    ORD1001    Backpack  Accessories         1   1629.00  Hyderabad
# 1    ORD1002    Keyboard  Electronics         2   1570.94      Surat
# 2    ORD1003        Book        Books         4    407.86     Mumbai
# 3    ORD1004    Keyboard  Electronics         5   1530.61      Surat
# 4    ORD1005      Tablet  Electronics         5  27549.31     Jaipur
# ..       ...         ...          ...       ...       ...        ...
# 995  ORD1996       Watch  Accessories         5   4711.82  Ahmedabad
# 996  ORD1997     T-Shirt      Fashion         5    861.96      Surat
# 997  ORD1998    Backpack  Accessories         2   1751.69  Bangalore
# 998  ORD1999      Tablet  Electronics         3  25949.74      Surat
# 999  ORD2000  Smartphone  Electronics         4  17509.92  Ahmedabad
#
#            Date
# 0    2026-03-04
# 1    2026-01-23
# 2    2026-02-25
# 3    2026-02-20
# 4    2026-05-31
# ..          ...
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called sales.

# %%
sales = pd.read_csv("7_ecommerce_sales_1000_records - 7_ecommerce_sales_1000_records.csv")

# %% [markdown]
# ### Step 4. Display the first 10 rows of the dataset.

# %%
sales.head(10)
# Out:
#   Order_ID     Product     Category  Quantity     Price       City        Date
# 0  ORD1001    Backpack  Accessories         1   1629.00  Hyderabad  2026-03-04
# 1  ORD1002    Keyboard  Electronics         2   1570.94      Surat  2026-01-23
# 2  ORD1003        Book        Books         4    407.86     Mumbai  2026-02-25
# 3  ORD1004    Keyboard  Electronics         5   1530.61      Surat  2026-02-20
# 4  ORD1005      Tablet  Electronics         5  27549.31     Jaipur  2026-05-31
# 5  ORD1006     T-Shirt      Fashion         1    840.36      Delhi  2026-06-28
# 6  ORD1007       Watch  Accessories         3   4776.92  Bangalore  2026-03-28
# 7  ORD1008  Smartphone  Electronics         1  17567.74       Pune  2026-03-30
# 8  ORD1009        Book        Books         3    477.64     Jaipur  2026-05-18
# 9  ORD1010  Smartphone  Electronics         4  16483.68  Hyderabad  2026-06-10

# %% [markdown]
# ### Step 5. What is the total number of observations (rows) in the dataset?

# %%
sales.shape[1]
# Out:
# 7

# %% [markdown]
# ### Step 6. What is the total number of columns in the dataset?

# %%
sales.shape[0]
# Out:
# 1000

# %% [markdown]
# ### Step 7. Print the names of all the columns.

# %%
sales.columns
# Out:
# Index(['Order_ID', 'Product', 'Category', 'Quantity', 'Price', 'City', 'Date'], dtype='str')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# ### Step 9. Display the data types of all columns.

# %%
sales.dtypes
# Out:
# Order_ID        str
# Product         str
# Category        str
# Quantity      int64
# Price       float64
# City            str
# Date            str
# dtype: object

# %% [markdown]
# ### Step 10. Check if there are any missing values in the dataset.

# %%
sales.isnull().sum()
# Out:
# Order_ID    0
# Product     0
# Category    0
# Quantity    0
# Price       0
# City        0
# Date        0
# dtype: int64

# %% [markdown]
# ### Step 11. How many unique products are available?

# %%
sales['Product'].nunique()
# Out:
# 14

# %% [markdown]
# ### Step 12. Which product was sold the most (based on total quantity)?

# %%
sales.groupby('Product')['Quantity'].sum().idxmax()
# Out:
# 'T-Shirt'

# %% [markdown]
# ### Step 13. How many units of the most sold product were purchased?

# %%
sales.groupby('Product')['Quantity'].sum().max()
# Out:
# np.int64(259)

# %% [markdown]
# ### Step 14. Which category generated the highest total sales revenue?

# %%
sales.groupby('Category')['Price'].sum().idxmax()
# Out:
# 'Electronics'

# %% [markdown]
# ### Step 15. Which city placed the highest number of orders?

# %%
sales.groupby('City')['Quantity'].sum().idxmax()
# Out:
# 'Mumbai'

# %% [markdown]
# ### Step 16. What is the total quantity of products sold?

# %% [markdown]
# ### Step 17. Calculate the total revenue of the dataset.

# %% [markdown]
# ### Step 18. What is the average order value?

# %% [markdown]
# ### Step 19. Which product generated the highest revenue?

# %% [markdown]
# ### Step 20. Which city generated the highest total revenue?

# %% [markdown]
# ### Step 21. On which date was the maximum revenue generated?

# %% [markdown]
# ### Step 22. Which category has the highest average product price?

# %% [markdown]
# ### Step 23. Find the top 10 best-selling products based on quantity sold.

# %% [markdown]
# ### Step 24. Find the top 5 cities by total revenue.

# %% [markdown]
# ### Step 25. Which product has the highest average selling price?

# %% [markdown]
# ### Step 26. What is the average quantity purchased per order?

# %% [markdown]
# ### Step 27. How many orders were placed in each category?

# %% [markdown]
# ### Step 28. Find the total revenue generated by each category.

# %% [markdown]
# ### Step 29. Sort the dataset by Price in descending order and display the top 10 records.

# %% [markdown]
# ### Step 30. Create a new column called Revenue = Quantity × Price and display the first 10 rows.

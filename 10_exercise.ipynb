# %% [markdown]
# ### Step 1. How many job listings are available in the dataset?

# %%
import pandas as pd

# %%
df = pd.read_csv("10_indian_tech_jobs_2026 - 10_indian_tech_jobs_2026.csv")
df
# Out:
#        job_id                                        job_title  \
# 0           1                                   Data Scientist
# 1           2                                   Data Scientist
# 2           3                         Analytics Data Scientist
# 3           4                                   Data Scientist
# 4           5             Sr. Artificial Intelligence Engineer
# ...       ...                                              ...
# 23196   23197                       Python Developer-Hyderabad
# 23197   23198                                 Python Developer
# 23198   23199  Walk in Interview Python Developer II Hyderabad
# 23199   23200                                 Python Developer
# 23200   23201                                 Python Developer
#
#                           company_name  company_rating  \
# 0                                Cisco             4.1
# 1                      Caterpillar Inc             4.1
# 2            Foreign IT Consulting MNC             3.6
# 3      Fortune 500 IT Services Company             3.6
# 4        Fortune 500 Product-based MNC             3.6
# ...                                ...             ...
# 23196                          Infosys             3.5
# 23197                           Accufy             3.6
# 23198        Tata Consultancy Services             3.3
# 23199                        Mediamint             2.8
# 23200           CMM Level 5 IT Company             3.6
#
#                                   location scraped_city     role_category  \
# 0                                Bengaluru    Bangalore    Data Scientist
# 1                                Bengaluru    Bangalore    Data Scientist
# 2            Hyderabad, Chennai, Bengaluru    Bangalore    Data Scientist
# 3                        Mumbai, Bengaluru    Bangalore    Data Scientist
# 4                          Pune, Bengaluru    Bangalore    Data Scientist
# ...                                    ...          ...               ...
# 23196                   Hybrid - Hyderabad    Hyderabad  Python Developer
# 23197                            Hyderabad    Hyderabad  Python Developer
# 23198  Hyderabad, Pune, Mumbai (All Areas)    Hyderabad  Python Developer
# 23199                   Hybrid - Hyderabad    Hyderabad  Python Developer
# 23200                            Hyderabad    Hyderabad  Python Developer
#
#       experience_raw  experience_min_yrs  experience_max_yrs  ...  scraped_at  \
# 0           7-10 Yrs                   7                  10  ...  2025-06-10
# 1            4-8 Yrs                   4                   8  ...  2025-06-10
# 2            4-9 Yrs                   4                   9  ...  2025-06-10
# 3          10-14 Yrs                   0                   0  ...  2025-06-10
# 4           5-10 Yrs                   5                  10  ...  2025-06-10
# ...              ...                 ...                 ...  ...         ...
# 23196        2-7 Yrs                   2                   7  ...  2025-06-10
# 23197        0-4 Yrs                   0                   4  ...  2025-06-10
# 23198         13 Jun                  13                   8  ...  2025-06-10
# 23199        3-5 Yrs                   3                   5  ...  2025-06-10
# 23200       7-12 Yrs                   7                  12  ...  2025-06-10
#
#               salary_tier          experience_tier  is_senior primary_city  \
# 0             Undisclosed         Senior (6-8 Yrs)      False    Bangalore
# 1             Undisclosed            Mid (3-5 Yrs)      False    Bangalore
# 2             Undisclosed            Mid (3-5 Yrs)      False    Hyderabad
# 3             Undisclosed                  Fresher      False       Mumbai
# 4             Undisclosed            Mid (3-5 Yrs)       True         Pune
# ...                   ...                      ...        ...          ...
# 23196         Undisclosed         Junior (0-2 Yrs)      False    Hyderabad
# 23197         Undisclosed                  Fresher      False    Hyderabad
# 23198         Undisclosed  Lead/Architect (9+ Yrs)      False    Hyderabad
# 23199         Undisclosed            Mid (3-5 Yrs)      False    Hyderabad
# 23200  Senior (10-20 LPA)         Senior (6-8 Yrs)      False    Hyderabad
#
#                 skill_domain salary_midpoint_lpa days_since_posted  \
# 0      Business Intelligence                 0.0                21
# 1                   AI/ML/DL                 0.0                21
# 2      Business Intelligence                 0.0                21
# 3               Data Science                 0.0                21
# 4               Data Science                 0.0                21
# ...                      ...                 ...               ...
# 23196           Data Science                 0.0                 1
# 23197           Data Science                 0.0                 1
# 23198       Data Engineering                 0.0                21
# 23199           Data Science                 0.0                 0
# 23200           Data Science                13.0                 1
#
#       is_fresher_friendly salary_negotiable
# 0                   False             False
# 1                   False             False
# 2                   False             False
# 3                    True             False
# 4                   False             False
# ...                   ...               ...
# 23196               False             False
# 23197                True             False
# 23198               False             False
# 23199               False             False
# 23200               False             False
#
# [23201 rows x 32 columns]

# %%
df.job_title.nunique()
# Out:
# 13128

# %% [markdown]
# ### Step 2. How many features (columns) are present in the dataset?

# %%
df.shape[1]
# Out:
# 32

# %% [markdown]
# ### Step 3. Display the names and data types of all columns.

# %%
df.dtypes
# Out:
# job_id                   int64
# job_title                  str
# company_name               str
# company_rating         float64
# location                   str
# scraped_city               str
# role_category              str
# experience_raw             str
# experience_min_yrs       int64
# experience_max_yrs       int64
# salary_raw                 str
# salary_min_lpa         float64
# salary_max_lpa         float64
# salary_disclosed          bool
# skills_required            str
# skills_count             int64
# job_description            str
# posted_date_raw            str
# work_mode                  str
# company_size_bucket        str
# job_url                    str
# data_source                str
# scraped_at                 str
# salary_tier                str
# experience_tier            str
# is_senior                 bool
# primary_city               str
# skill_domain               str
# salary_midpoint_lpa    float64
# days_since_posted        int64
# is_fresher_friendly       bool
# salary_negotiable         bool
# dtype: object

# %% [markdown]
# ### Step 4. Check whether there are any missing values in each column.

# %%
df.isnull().sum()
# Out:
# job_id                  0
# job_title               0
# company_name            0
# company_rating          0
# location                0
# scraped_city            0
# role_category           0
# experience_raw          0
# experience_min_yrs      0
# experience_max_yrs      0
# salary_raw              0
# salary_min_lpa          0
# salary_max_lpa          0
# salary_disclosed        0
# skills_required         0
# skills_count            0
# job_description         0
# posted_date_raw         0
# work_mode               0
# company_size_bucket     0
# job_url                53
# data_source             0
# scraped_at              0
# salary_tier             0
# experience_tier         0
# is_senior               0
# primary_city            0
# skill_domain            0
# salary_midpoint_lpa     0
# days_since_posted       0
# is_fresher_friendly     0
# salary_negotiable       0
# dtype: int64

# %% [markdown]
# ### Step 5. How many unique companies have posted jobs?

# %%
df.company_name.unique()
# Out:
# <StringArray>
# [                          'Cisco',                 'Caterpillar Inc',
#        'Foreign IT Consulting MNC', 'Fortune 500 IT Services Company',
#    'Fortune 500 Product-based MNC',         'Top Rated IT Enterprise',
#                  'Leading IT Firm',         'Exxon Mobil Corporation',
#                           'Google',                            'Hsbc',
#  ...
#             'Digixpressions Media',              'Direction Software',
#            'Solsynch Technologies',               'Rite Technologies',
#               'Manav It Solutions',              'Optiminastic Media',
#                        'Cart Geek',    'Cybertech Systems & Software',
#                           'Accufy',                       'Mediamint']
# Length: 6993, dtype: str

# %% [markdown]
# ### Step 6. Which company has posted the highest number of job openings?

# %% [markdown]
# ### Step 7. How many job openings does the company with the most postings have?

# %% [markdown]
# ### Step 8. Which city has the highest number of job postings?

# %% [markdown]
# ### Step 9. Find the top 10 cities with the most job opportunities.

# %% [markdown]
# ### Step 10. Which job title appears most frequently in the dataset?

# %% [markdown]
# ### Step 11. How many times was the most common job title posted?

# %% [markdown]
# ### Step 12. What is the average minimum salary (salary_min_lpa) offered across all jobs with disclosed salaries?

# %% [markdown]
# ### Step 13. What is the average maximum salary (salary_max_lpa) offered across all jobs with disclosed salaries?

# %% [markdown]
# ### Step 14. Which company offers the highest average salary midpoint (salary_midpoint_lpa)? (Consider companies with at least 5 job postings.)

# %% [markdown]
# ### Step 15. Which work mode (On-site, Hybrid, Remote, etc.) has the highest average salary midpoint?

# %% [markdown]
# ### Bonus (Slightly More Challenging)
# ### Step 21. Which city offers the highest average salary midpoint for Data Science-related roles?

# %% [markdown]
# ### Step 22. Find the percentage of jobs that have salary information disclosed.

# %% [markdown]
# ### Step 23. Which experience tier has the highest average salary midpoint?

# %% [markdown]
# ### Step 24. Find the top 10 companies hiring for Senior-level positions.

# %% [markdown]
# ### Step 25. Which companies have both fresher-friendly jobs and senior-level jobs?

# %% [markdown]
# ### Step 26. Which city has the highest proportion of Remote jobs?

# %% [markdown]
# ### Step 27. Find the average number of required skills (skills_count) for each role category.

# %% [markdown]
# ### Step 28. Which company has the greatest variety of job titles?

# %% [markdown]
# ### Step 29. Among companies with disclosed salaries, which company offers the highest maximum salary (salary_max_lpa)?

# %% [markdown]
# ### Step 30. Create a summary table showing, for each work mode:
# ### Number of job postings
# ### Average salary midpoint
# ### Average company rating
# ### Percentage of fresher-friendly jobs
